# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani378/CODETECH-Task1/blob/main/Basics_of_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***DATA MANIPULATION AND ANALYSIS USING PANDAS***

# %% [markdown]
# In Machine learning we need dataset to operate the algorithm, and dataset may be of training and testing data.
#
# When we are looking for dataset from various platforms and regions, we will be getting the dataset that consists of NAN, NULL and various other forms.
#
# So it is important to modify and clean the data for better insights.
#
# PANDAS is a famous library of python which helps us in giving out the accurate insights of the data.

# %% [markdown]
# ** Before moving forward, ensure that Pandas is installed in your system**

# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from opendatasets) (4.67.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (from opendatasets) (1.7.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from opendatasets) (8.1.8)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2025.1.31)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (3.4.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (5.29.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (75.1.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2.3.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (0.5.1)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/atharvasoundankar/global-tech-gadget-consumption-data-2015-2025" )
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: shivanishivani123
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/atharvasoundankar/global-tech-gadget-consumption-data-2015-2025

# %%
#Use this to install pandas

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#Importing of pandas library
import pandas as pd

# %% [markdown]
# Basic operations using pandas

# %%
#Creating a new DataFrame
df1 = pd.DataFrame({'A':[1,2,3,4],'B':['hello','how','are','you']})

# %%
df1
# Out:
#    A      B
# 0  1  hello
# 1  2    how
# 2  3    are
# 3  4    you

# %% [markdown]
# Data Frame is being created, where [ A,B ] are the names of columns

# %%
df1.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %% [markdown]
# *** Loading of the data ***

# %%
import pandas as pd
df = pd.read_csv("/content/global-tech-gadget-consumption-data-2015-2025/Global_Tech_Gadget_Consumption.csv")

# %% [markdown]
# *** Data Exploration ***

# %%
df.head()

#View top rows
# Out:
#   Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 0     USA  2015                       111.37                       123.63
# 1     USA  2016                       224.65                        65.27
# 2     USA  2017                       102.12                        26.75
# 3     USA  2018                       148.10                       129.28
# 4     USA  2019                        83.93                        97.81
#
#    Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 0                        12.05                       14.49
# 1                        12.92                        9.88
# 2                        19.63                       17.35
# 3                        26.44                       12.45
# 4                        20.84                        6.18
#
#    Average Consumer Spending on Gadgets ($)  E-Waste Generated (Metric Tons)  \
# 0                                    311.21                           939.89
# 1                                    250.46                          1361.42
# 2                                   2404.22                           872.52
# 3                                   1883.37                          1241.41
# 4                                    777.42                          1939.39
#
#    5G Penetration Rate (%)
# 0                    54.64
# 1                    53.61
# 2                    29.94
# 3                    75.88
# 4                    76.26

# %%
df.tail()

#View bottom rows
# Out:
#     Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 105  Canada  2021                       458.94                        25.18
# 106  Canada  2022                       124.51                       132.45
# 107  Canada  2023                        82.40                        90.87
# 108  Canada  2024                       382.35                       135.66
# 109  Canada  2025                       194.84                       148.29
#
#      Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 105                        36.58                       12.61
# 106                        25.12                        5.59
# 107                        37.58                       22.00
# 108                        39.39                       23.25
# 109                        17.07                       10.25
#
#      Average Consumer Spending on Gadgets ($)  \
# 105                                   2765.28
# 106                                   2740.43
# 107                                   1770.03
# 108                                   2061.97
# 109                                   1156.52
#
#      E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# 105                          1954.06                    32.34
# 106                           251.69                    73.44
# 107                          1368.87                    53.54
# 108                          1783.59                     5.91
# 109                           165.18                    14.86

# %%
df.head(300)

#view first 300 rows
# Out:
#     Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 0       USA  2015                       111.37                       123.63
# 1       USA  2016                       224.65                        65.27
# 2       USA  2017                       102.12                        26.75
# 3       USA  2018                       148.10                       129.28
# 4       USA  2019                        83.93                        97.81
# ..      ...   ...                          ...                          ...
# 105  Canada  2021                       458.94                        25.18
# 106  Canada  2022                       124.51                       132.45
# 107  Canada  2023                        82.40                        90.87
# 108  Canada  2024                       382.35                       135.66
# 109  Canada  2025                       194.84                       148.29
#
#      Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 0                          12.05                       14.49
# 1                          12.92                        9.88
# 2                          19.63                       17.35
# 3                          26.44                       12.45
# 4                          20.84                        6.18
# ..                           ...                         ...
# 105                        36.58                       12.61
# 106                        25.12                        5.59
# 107                        37.58                       22.00
# 108                        39.39                       23.25
# 109                        17.07                       10.25
#
#      Average Consumer Spending on Gadgets ($)  \
# 0                                      311.21
# 1                                      250.46
# 2                                     2404.22
# 3                                     1883.37
# 4                                      777.42
# ..                                        ...
# 105                                   2765.28
# 106                                   2740.43
# 107                                   1770.03
# 108                                   2061.97
# 109                                   1156.52
#
#      E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# 0                             939.89                    54.64
# 1                            1361.42                    53.61
# 2                             872.52                    29.94
# 3                            1241.41                    75.88
# 4                            1939.39                    76.26
# ..                               ...                      ...
# 105                          1954.06                    32.34
# 106                           251.69                    73.44
# 107                          1368.87                    53.54
# 108                          1783.59                     5.91
# 109                           165.18                    14.86
#
# [110 rows x 9 columns]

# %%
df.describe()

#Statistics Summary
# Out:
#              Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# count   110.00000                   110.000000                   110.000000
# mean   2020.00000                   269.095545                    86.082000
# std       3.17675                   128.313552                    36.429392
# min    2015.00000                    64.000000                    20.790000
# 25%    2017.00000                   156.910000                    59.412500
# 50%    2020.00000                   253.435000                    87.450000
# 75%    2023.00000                   376.255000                   113.965000
# max    2025.00000                   499.890000                   149.210000
#
#        Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# count                   110.000000                  110.000000
# mean                     21.753545                   14.129818
# std                       9.748557                    6.353190
# min                       5.490000                    2.040000
# 25%                      13.737500                    8.982500
# 50%                      20.365000                   14.520000
# 75%                      28.460000                   19.815000
# max                      39.470000                   24.810000
#
#        Average Consumer Spending on Gadgets ($)  \
# count                                110.000000
# mean                                1571.539182
# std                                  816.552255
# min                                  220.090000
# 25%                                  856.957500
# 50%                                 1592.145000
# 75%                                 2195.960000
# max                                 2989.540000
#
#        E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# count                       110.000000               110.000000
# mean                       1035.352636                42.816273
# std                         562.591157                21.888573
# min                         111.470000                 2.990000
# 25%                         570.250000                23.952500
# 50%                        1023.270000                45.735000
# 75%                        1487.847500                58.900000
# max                        1962.590000                79.340000

# %%
df.dtypes

#Kind of data present in each column
# Out:
# Country                                      object
# Year                                          int64
# Smartphone Sales (Millions)                 float64
# Laptop Shipments (Millions)                 float64
# Gaming Console Adoption (%)                 float64
# Smartwatch Penetration (%)                  float64
# Average Consumer Spending on Gadgets ($)    float64
# E-Waste Generated (Metric Tons)             float64
# 5G Penetration Rate (%)                     float64
# dtype: object

# %%
df.isnull().sum()

#Finding out the missing values count in each and every column
# Out:
# Country                                     0
# Year                                        0
# Smartphone Sales (Millions)                 0
# Laptop Shipments (Millions)                 0
# Gaming Console Adoption (%)                 0
# Smartwatch Penetration (%)                  0
# Average Consumer Spending on Gadgets ($)    0
# E-Waste Generated (Metric Tons)             0
# 5G Penetration Rate (%)                     0
# dtype: int64

# %% [markdown]
# *** Data Selection ***

# %%
df['Year']

#select a particular column --->>> df["name_of_column"]
# Out:
# 0      2015
# 1      2016
# 2      2017
# 3      2018
# 4      2019
#        ...
# 105    2021
# 106    2022
# 107    2023
# 108    2024
# 109    2025
# Name: Year, Length: 110, dtype: int64

# %%
df[['Smartphone Sales (Millions)','Year']]

#Select multiple columns --->>> df[["column_1","column_2"]]
# Out:
#      Smartphone Sales (Millions)  Year
# 0                         111.37  2015
# 1                         224.65  2016
# 2                         102.12  2017
# 3                         148.10  2018
# 4                          83.93  2019
# ..                           ...   ...
# 105                       458.94  2021
# 106                       124.51  2022
# 107                        82.40  2023
# 108                       382.35  2024
# 109                       194.84  2025
#
# [110 rows x 2 columns]

# %%
v = df[['Year','Smartphone Sales (Millions)','Laptop Shipments (Millions)']]

# %%
v
# Out:
#       Age  Survived            Ticket
# 0    22.0         0         A/5 21171
# 1    38.0         1          PC 17599
# 2    26.0         1  STON/O2. 3101282
# 3    35.0         1            113803
# 4    35.0         0            373450
# ..    ...       ...               ...
# 886  27.0         0            211536
# 887  19.0         1            112053
# 888   NaN         0        W./C. 6607
# 889  26.0         1            111369
# 890  32.0         0            370376
#
# [891 rows x 3 columns]

# %%
type(v)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Year'][1:100:3]

#Selecting rows with the help of indexing --->>> df.iloc[start_index : End_index : Jump]
# Out:
# 1     2016
# 4     2019
# 7     2022
# 10    2025
# 13    2017
# 16    2020
# 19    2023
# 22    2015
# 25    2018
# 28    2021
# 31    2024
# 34    2016
# 37    2019
# 40    2022
# 43    2025
# 46    2017
# 49    2020
# 52    2023
# 55    2015
# 58    2018
# 61    2021
# 64    2024
# 67    2016
# 70    2019
# 73    2022
# 76    2025
# 79    2017
# 82    2020
# 85    2023
# 88    2015
# 91    2018
# 94    2021
# 97    2024
# Name: Year, dtype: int64

# %%
df[['Laptop Shipments (Millions)','Year']][1:50:4]
# Out:
#     Laptop Shipments (Millions)  Year
# 1                         65.27  2016
# 5                        100.59  2020
# 9                         58.60  2024
# 13                        99.05  2017
# 17                       117.16  2021
# 21                        45.20  2025
# 25                       114.65  2018
# 29                        44.12  2022
# 33                       107.09  2015
# 37                        65.04  2019
# 41                        98.82  2023
# 45                        27.25  2016
# 49                       107.03  2020

# %%
df.columns

#view of all the columns present in the dataset
# Out:
# Index(['Country', 'Year', 'Smartphone Sales (Millions)',
#        'Laptop Shipments (Millions)', 'Gaming Console Adoption (%)',
#        'Smartwatch Penetration (%)',
#        'Average Consumer Spending on Gadgets ($)',
#        'E-Waste Generated (Metric Tons)', '5G Penetration Rate (%)'],
#       dtype='object')

# %%
df.iloc[1:5]

#Here we are selecting rows with the help of indexing

# iloc [1:5] ---->> Start from index 1 and go till index 4 (exclude last index from condition same like of indexing in any coding language)
# Out:
#   Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 1     USA  2016                       224.65                        65.27
# 2     USA  2017                       102.12                        26.75
# 3     USA  2018                       148.10                       129.28
# 4     USA  2019                        83.93                        97.81
#
#    Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 1                        12.92                        9.88
# 2                        19.63                       17.35
# 3                        26.44                       12.45
# 4                        20.84                        6.18
#
#    Average Consumer Spending on Gadgets ($)  E-Waste Generated (Metric Tons)  \
# 1                                    250.46                          1361.42
# 2                                   2404.22                           872.52
# 3                                   1883.37                          1241.41
# 4                                    777.42                          1939.39
#
#    5G Penetration Rate (%)
# 1                    53.61
# 2                    29.94
# 3                    75.88
# 4                    76.26

# %%
df.iloc[0:5]

#start from 0th index and go till 4th index
# Out:
#   Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 0     USA  2015                       111.37                       123.63
# 1     USA  2016                       224.65                        65.27
# 2     USA  2017                       102.12                        26.75
# 3     USA  2018                       148.10                       129.28
# 4     USA  2019                        83.93                        97.81
#
#    Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 0                        12.05                       14.49
# 1                        12.92                        9.88
# 2                        19.63                       17.35
# 3                        26.44                       12.45
# 4                        20.84                        6.18
#
#    Average Consumer Spending on Gadgets ($)  E-Waste Generated (Metric Tons)  \
# 0                                    311.21                           939.89
# 1                                    250.46                          1361.42
# 2                                   2404.22                           872.52
# 3                                   1883.37                          1241.41
# 4                                    777.42                          1939.39
#
#    5G Penetration Rate (%)
# 0                    54.64
# 1                    53.61
# 2                    29.94
# 3                    75.88
# 4                    76.26

# %%
df['Year']>10

#Checking the condition for a column --->>> df["column_name"]condition
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 105    True
# 106    True
# 107    True
# 108    True
# 109    True
# Name: Year, Length: 110, dtype: bool

# %%
df[df['Year']>10]

#Accesing of entire rows with the condition for particular column

# df[df['column_name']condition]
# Out:
#     Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 0       USA  2015                       111.37                       123.63
# 1       USA  2016                       224.65                        65.27
# 2       USA  2017                       102.12                        26.75
# 3       USA  2018                       148.10                       129.28
# 4       USA  2019                        83.93                        97.81
# ..      ...   ...                          ...                          ...
# 105  Canada  2021                       458.94                        25.18
# 106  Canada  2022                       124.51                       132.45
# 107  Canada  2023                        82.40                        90.87
# 108  Canada  2024                       382.35                       135.66
# 109  Canada  2025                       194.84                       148.29
#
#      Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 0                          12.05                       14.49
# 1                          12.92                        9.88
# 2                          19.63                       17.35
# 3                          26.44                       12.45
# 4                          20.84                        6.18
# ..                           ...                         ...
# 105                        36.58                       12.61
# 106                        25.12                        5.59
# 107                        37.58                       22.00
# 108                        39.39                       23.25
# 109                        17.07                       10.25
#
#      Average Consumer Spending on Gadgets ($)  \
# 0                                      311.21
# 1                                      250.46
# 2                                     2404.22
# 3                                     1883.37
# 4                                      777.42
# ..                                        ...
# 105                                   2765.28
# 106                                   2740.43
# 107                                   1770.03
# 108                                   2061.97
# 109                                   1156.52
#
#      E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# 0                             939.89                    54.64
# 1                            1361.42                    53.61
# 2                             872.52                    29.94
# 3                            1241.41                    75.88
# 4                            1939.39                    76.26
# ..                               ...                      ...
# 105                          1954.06                    32.34
# 106                           251.69                    73.44
# 107                          1368.87                    53.54
# 108                          1783.59                     5.91
# 109                           165.18                    14.86
#
# [110 rows x 9 columns]

# %% [markdown]
# *** Data Manipulation ***

# %%
df
# Out:
#     Country  How many years  Smartphone Sales (Millions)  \
# 0       USA            2015                       111.37
# 1       USA            2016                       224.65
# 2       USA            2017                       102.12
# 3       USA            2018                       148.10
# 4       USA            2019                        83.93
# ..      ...             ...                          ...
# 105  Canada            2021                       458.94
# 106  Canada            2022                       124.51
# 107  Canada            2023                        82.40
# 108  Canada            2024                       382.35
# 109  Canada            2025                       194.84
#
#      Laptop Shipments (Millions)  Gaming Console Adoption (%)  \
# 0                         123.63                        12.05
# 1                          65.27                        12.92
# 2                          26.75                        19.63
# 3                         129.28                        26.44
# 4                          97.81                        20.84
# ..                           ...                          ...
# 105                        25.18                        36.58
# 106                       132.45                        25.12
# 107                        90.87                        37.58
# 108                       135.66                        39.39
# 109                       148.29                        17.07
#
#      Smartwatch Penetration (%)  Average Consumer Spending on Gadgets ($)  \
# 0                         14.49                                    311.21
# 1                          9.88                                    250.46
# 2                         17.35                                   2404.22
# 3                         12.45                                   1883.37
# 4                          6.18                                    777.42
# ..                          ...                                       ...
# 105                       12.61                                   2765.28
# 106                        5.59                                   2740.43
# 107                       22.00                                   1770.03
# 108                       23.25                                   2061.97
# 109                       10.25                                   1156.52
#
#      E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# 0                             939.89                    54.64
# 1                            1361.42                    53.61
# 2                             872.52                    29.94
# 3                            1241.41                    75.88
# 4                            1939.39                    76.26
# ..                               ...                      ...
# 105                          1954.06                    32.34
# 106                           251.69                    73.44
# 107                          1368.87                    53.54
# 108                          1783.59                     5.91
# 109                           165.18                    14.86
#
# [110 rows x 9 columns]

# %%
df
# Out:
#     Country  How many years  Smartphone Sales (Millions)  \
# 0       USA            2015                       111.37
# 1       USA            2016                       224.65
# 2       USA            2017                       102.12
# 3       USA            2018                       148.10
# 4       USA            2019                        83.93
# ..      ...             ...                          ...
# 105  Canada            2021                       458.94
# 106  Canada            2022                       124.51
# 107  Canada            2023                        82.40
# 108  Canada            2024                       382.35
# 109  Canada            2025                       194.84
#
#      Laptop Shipments (Millions)  Gaming Console Adoption (%)  \
# 0                         123.63                        12.05
# 1                          65.27                        12.92
# 2                          26.75                        19.63
# 3                         129.28                        26.44
# 4                          97.81                        20.84
# ..                           ...                          ...
# 105                        25.18                        36.58
# 106                       132.45                        25.12
# 107                        90.87                        37.58
# 108                       135.66                        39.39
# 109                       148.29                        17.07
#
#      Smartwatch Penetration (%)  Average Consumer Spending on Gadgets ($)  \
# 0                         14.49                                    311.21
# 1                          9.88                                    250.46
# 2                         17.35                                   2404.22
# 3                         12.45                                   1883.37
# 4                          6.18                                    777.42
# ..                          ...                                       ...
# 105                       12.61                                   2765.28
# 106                        5.59                                   2740.43
# 107                       22.00                                   1770.03
# 108                       23.25                                   2061.97
# 109                       10.25                                   1156.52
#
#      E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# 0                             939.89                    54.64
# 1                            1361.42                    53.61
# 2                             872.52                    29.94
# 3                            1241.41                    75.88
# 4                            1939.39                    76.26
# ..                               ...                      ...
# 105                          1954.06                    32.34
# 106                           251.69                    73.44
# 107                          1368.87                    53.54
# 108                          1783.59                     5.91
# 109                           165.18                    14.86
#
# [110 rows x 9 columns]

# %%
df.dtypes
# Out:
# Country                                      object
# How many years                                int64
# Smartphone Sales (Millions)                 float64
# Laptop Shipments (Millions)                 float64
# Gaming Console Adoption (%)                 float64
# Smartwatch Penetration (%)                  float64
# Average Consumer Spending on Gadgets ($)    float64
# E-Waste Generated (Metric Tons)             float64
# 5G Penetration Rate (%)                     float64
# dtype: object

# %% [markdown]
# We can find that two different columns are added

# %%
df
# Out:
#     Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 0       USA  2015                       111.37                       123.63
# 1       USA  2016                       224.65                        65.27
# 2       USA  2017                       102.12                        26.75
# 3       USA  2018                       148.10                       129.28
# 4       USA  2019                        83.93                        97.81
# ..      ...   ...                          ...                          ...
# 105  Canada  2021                       458.94                        25.18
# 106  Canada  2022                       124.51                       132.45
# 107  Canada  2023                        82.40                        90.87
# 108  Canada  2024                       382.35                       135.66
# 109  Canada  2025                       194.84                       148.29
#
#      Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 0                          12.05                       14.49
# 1                          12.92                        9.88
# 2                          19.63                       17.35
# 3                          26.44                       12.45
# 4                          20.84                        6.18
# ..                           ...                         ...
# 105                        36.58                       12.61
# 106                        25.12                        5.59
# 107                        37.58                       22.00
# 108                        39.39                       23.25
# 109                        17.07                       10.25
#
#      Average Consumer Spending on Gadgets ($)  \
# 0                                      311.21
# 1                                      250.46
# 2                                     2404.22
# 3                                     1883.37
# 4                                      777.42
# ..                                        ...
# 105                                   2765.28
# 106                                   2740.43
# 107                                   1770.03
# 108                                   2061.97
# 109                                   1156.52
#
#      E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# 0                             939.89                    54.64
# 1                            1361.42                    53.61
# 2                             872.52                    29.94
# 3                            1241.41                    75.88
# 4                            1939.39                    76.26
# ..                               ...                      ...
# 105                          1954.06                    32.34
# 106                           251.69                    73.44
# 107                          1368.87                    53.54
# 108                          1783.59                     5.91
# 109                           165.18                    14.86
#
# [110 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Country', 'How many years', 'Smartphone Sales (Millions)',
#        'Laptop Shipments (Millions)', 'Gaming Console Adoption (%)',
#        'Smartwatch Penetration (%)',
#        'Average Consumer Spending on Gadgets ($)',
#        'E-Waste Generated (Metric Tons)', '5G Penetration Rate (%)'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %%
#Renaming of the columns

df = df.rename(columns={'Year':'How many years'})

# %%
df
# Out:
#     Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 0       USA  2015                       111.37                       123.63
# 1       USA  2016                       224.65                        65.27
# 2       USA  2017                       102.12                        26.75
# 3       USA  2018                       148.10                       129.28
# 4       USA  2019                        83.93                        97.81
# ..      ...   ...                          ...                          ...
# 105  Canada  2021                       458.94                        25.18
# 106  Canada  2022                       124.51                       132.45
# 107  Canada  2023                        82.40                        90.87
# 108  Canada  2024                       382.35                       135.66
# 109  Canada  2025                       194.84                       148.29
#
#      Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 0                          12.05                       14.49
# 1                          12.92                        9.88
# 2                          19.63                       17.35
# 3                          26.44                       12.45
# 4                          20.84                        6.18
# ..                           ...                         ...
# 105                        36.58                       12.61
# 106                        25.12                        5.59
# 107                        37.58                       22.00
# 108                        39.39                       23.25
# 109                        17.07                       10.25
#
#      Average Consumer Spending on Gadgets ($)  \
# 0                                      311.21
# 1                                      250.46
# 2                                     2404.22
# 3                                     1883.37
# 4                                      777.42
# ..                                        ...
# 105                                   2765.28
# 106                                   2740.43
# 107                                   1770.03
# 108                                   2061.97
# 109                                   1156.52
#
#      E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# 0                             939.89                    54.64
# 1                            1361.42                    53.61
# 2                             872.52                    29.94
# 3                            1241.41                    75.88
# 4                            1939.39                    76.26
# ..                               ...                      ...
# 105                          1954.06                    32.34
# 106                           251.69                    73.44
# 107                          1368.87                    53.54
# 108                          1783.59                     5.91
# 109                           165.18                    14.86
#
# [110 rows x 9 columns]

# %%
df['How many years'][0:4]
# Out:
# 0    2015
# 1    2016
# 2    2017
# 3    2018
# Name: How many years, dtype: int64
